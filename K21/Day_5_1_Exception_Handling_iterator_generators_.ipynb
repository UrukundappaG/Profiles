# %% [markdown]
# ---
#
#  ◀ ◀ ◀ ◀ ◀  🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 ▶ ▶ ▶ ▶ ▶
#
#  ---

# %% [markdown]
# #Welcome to the session !!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
#
#  ◀ ◀ ◀ ◀ ◀  🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 ▶ ▶ ▶ ▶ ▶
#
#  ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **EXCEPTION HANDLING**
# ---
#
# - Program that may behave abnormally or  Unexpectedly because of some errors and  exceptions.
#
# There are two kind of errors :- Syntax Errors &  Logical Error
#
# - **Logical error** occur due to poor understanding of  problem and its solution.
#
# - **Syntax error** aries due to poor understanding of  language.Such errors can be detected by  exhaustive debugging and testing of procedure.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Exception Handling Assignment**
# ---
# ---

# %% [markdown]
# #### **Task: Write a Python program that handles exceptions for the following cases:**
# ---
# ---
#
# **1. Division by Zero**
#
# Handle ZeroDivisionError when dividing two numbers.
#
# ---
# Example:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2. Invalid Input (ValueError)**
#
# Ask the user to enter a number and handle invalid inputs.
#
# ---
# Example:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. File Handling (FileNotFoundError)**
# Try to open a file (data.txt) and handle missing files.
#
# ---
# Example:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Using else and finally

# %% [markdown]
# ## Raising Your Own Exception

# %% [markdown]
# ## **Handling File Not Found Error**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **1. What is the purpose of a try-except block?**
#
# A) To skip code execution.
#
# B) To handle runtime errors gracefully.
#
# C) To speed up the program.
#
# D) To define custom functions.

# %% [markdown]
# ### **2. Which exception is raised for invalid type conversion?**
#
# A) ZeroDivisionError
#
# B) FileNotFoundError
#
# C) ValueError
#
# D) IndexError

# %% [markdown]
# ### **3. What happens if except is missing in a try block?**
#
# A) The program crashes if an error occurs.
#
# B) The program runs faster.
#
# C) Python ignores the error.
#
# D) It becomes a syntax error.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - A generator is a special type of iterator that is simpler to write using the yield keyword.
#
# **Key Differences from Iterator:**
# - No need to write __iter__() and __next__().
#
# - Automatically creates __iter__() and __next__() behind the scenes.
#
# - Saves memory using lazy evaluation — generates items on the fly.

# %% [markdown]
# - iter() gives you an iterator object.
# - next() fetches one item at a time. When no items are left, it raises StopIteration.

# %% [markdown]
# ---
#
#  ◀ ◀ ◀ ◀ ◀  🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 🔥🔥 🔥 🔥 🔥 🔥 ▶ ▶ ▶ ▶ ▶
#
#  ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)
